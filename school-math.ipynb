# %%
import numpy as np
from matplotlib import pyplot as plt

print("START")
# Out:
# START

# %%
from math import pi

r = 20

fig, ax = plt.subplots()

x = np.cos(np.arange(-pi, pi, pi/10))
y = np.sin(np.arange(-pi, pi, pi/10))
l = np.arange(-pi, pi, pi/10)

ax.plot(l, x, label='Cos')
ax.plot(l, y, label='Sin')

leg = ax.legend()
plt.show()

# %%
r1 = 15
x1 = np.arange(-1*r1, r1+0.01, 0.01)
y1 = np.sqrt(abs(r1*r1 - x1*x1))

x = r * x
y = r * y

fig, ax = plt.subplots()
ax.scatter(x, y)
ax.plot(x1, y1)
ax.plot(x1, -1*y1)
ax.axis('equal')
leg = ax.legend();
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D

mpl.rcParams['legend.fontsize'] = 10

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
#ax = fig.gca(projection='3d')
ax.plot(np.zeros(x.shape), x, y, label='vertical')
ax.plot(x, np.zeros(x.shape), y, label='horizontal')
ax.plot(x, y, np.zeros(x.shape), label='desctop')

ax.legend()
ax.set_xlabel(r'X')
ax.set_ylabel(r'Y')
ax.set_zlabel(r'Z')
# Out:
# Text(0.5, 0, 'Z')

# %%
fig, ax = plt.subplots()

l = np.arange(-2*pi, 2*pi, pi/100)
y1 = np.cos(np.arange(-2*pi-pi*(2/3), 2*pi-pi*(2/3), pi/100))
y2 = np.cos(np.arange(-2*pi-pi*(1/3), 2*pi-pi*(1/3), pi/100))
y3 = np.cos(np.arange(-2*pi, 2*pi, pi/100))
y4 = y1 + y2 + y3

ax.grid(True)
ax.plot(l, y1, label='Sin1')
ax.plot(l, y2, label='Sin2')
ax.plot(l, y3, label='Sin3')
ax.plot(l, y4)

leg = ax.legend()
plt.show()

# %%
mpl.rcParams['legend.fontsize'] = 10

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
#ax = fig.gca(projection='3d')
l = np.arange(-pi, pi, pi/100)
c_width = np.cos(l)
c_hight = np.sin(l)

ax.plot(np.zeros(l.shape), c_width, c_hight, label='ver1')
ax.plot(np.ones(l.shape), c_width, c_hight, label ='ver2')

ax.set_xlabel(r'X')
ax.set_ylabel(r'Y')
ax.set_zlabel(r'Z')
ax.legend()

# %%
mpl.rcParams['legend.fontsize'] = 10

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
#ax = fig.gca(projection='3d')
l = np.linspace(pi/2, pi, 10, endpoint=True)
c_h = np.cos(l)
c_w = np.sin(l)
R = 5

x = 0
y = 0
z = -1

#ax.plot(np.zeros(l.shape), c_h, c_w, label='vertical')

x = np.linspace(pi/2, pi, 10, endpoint=True)
x = np.cos(x) * R

y = (np.sin(l)* -1)+1
tmp1 = np.cos(l); tmp2 = np.sin(c_h)-0.5;
ax.plot(tmp1, tmp2, c_w)
tmp1 = -1*np.cos(l); tmp2 = -1*np.sin(c_h)-0.5;
ax.plot(tmp1+R, tmp2+R, c_w)

#ax.legend()
ax.set_xlabel(r'X')
ax.set_ylabel(r'Y')
ax.set_zlabel(r'Z')
# Out:
# Text(0.5, 0, 'Z')
