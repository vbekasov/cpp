# %%
import numpy as np
#from matplotlib import pyplot as plt
# %matplotlib notebook

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d  

print("START")
# Out:
# START

# %%
from math import pi

r = 20

fig, ax = plt.subplots()

x = np.cos(np.arange(-pi, pi, pi/10))
y = np.sin(np.arange(-pi, pi, pi/10))
l = np.arange(-pi, pi, pi/10)

ax.plot(l, x, label='Cos')
ax.plot(l, y, label='Sin')

leg = ax.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
r1 = 15
x1 = np.arange(-1*r1, r1+0.01, 0.01)
y1 = np.sqrt(abs(r1*r1 - x1*x1))

x = r * x
y = r * y

fig, ax = plt.subplots()
ax.scatter(x, y)
ax.plot(x1, y1)
ax.plot(x1, -1*y1)
ax.axis('equal')
# Out:
# <img src="data:image/png;base64,..." width="640">
# (-22.0, 22.0, -22.0, 22.0)

# %%
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D

mpl.rcParams['legend.fontsize'] = 10

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
#ax = fig.gca(projection='3d')
ax.plot(np.zeros(x.shape), x, y, label='vertical')
ax.plot(x, np.zeros(x.shape), y, label='horizontal')
ax.plot(x, y, np.zeros(x.shape), label='desctop')

ax.legend()
ax.set_xlabel(r'X')
ax.set_ylabel(r'Y')
ax.set_zlabel(r'Z')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 0, 'Z')

# %%
fig, ax = plt.subplots()

l = np.arange(-2*pi, 2*pi, pi/100)
y1 = np.cos(np.arange(-2*pi-pi*(2/3), 2*pi-pi*(2/3), pi/100))
y2 = np.cos(np.arange(-2*pi-pi*(1/3), 2*pi-pi*(1/3), pi/100))
y3 = np.cos(np.arange(-2*pi, 2*pi, pi/100))
y4 = y1 + y2 + y3

ax.grid(True)
ax.plot(l, y1, label='Sin1')
ax.plot(l, y2, label='Sin2')
ax.plot(l, y3, label='Sin3')
ax.plot(l, y4)

leg = ax.legend()
plt.show()

del(y1); del(y2); del(y3); del(y4)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mpl.rcParams['legend.fontsize'] = 10

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
#ax = fig.gca(projection='3d')
l = np.arange(-pi, pi, pi/100)

ax.plot(np.zeros(l.shape), np.cos(l), np.sin(l), label='ver1')
ax.plot(np.ones(l.shape), np.cos(l), np.sin(l), label ='ver2')

ax.set_xlabel(r'X')
ax.set_ylabel(r'Y')
ax.set_zlabel(r'Z')
ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mpl.rcParams['legend.fontsize'] = 10

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
l = np.linspace(pi/2, pi, 10, endpoint=True)

R = 5

ax.plot(np.cos(l), np.sin(np.cos(l))-0.5, np.sin(l))
ax.plot(-1*np.cos(l)+R, -1*np.sin(np.cos(l))-0.5+R, np.sin(l))

ax.set_xlabel(r'X')
ax.set_ylabel(r'Y')
ax.set_zlabel(r'Z')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 0, 'Z')

# %%
mpl.rcParams['legend.fontsize'] = 10

fig = plt.figure()
ax = fig.add_subplot(projection='3d')

l = np.linspace(-pi, pi, 15, endpoint=True)
r = 1

ax.scatter(3, -3, -4)

ax.plot(np.cos(l)*r, np.zeros(l.size), np.sin(l)*r)
ax.scatter(np.cos(l)*r*0.5+0.75, np.zeros(l.size)+r-0.5, np.sin(l)*r*0.5)
#for it in np.linspace(1, 2, 5, endpoint=True):
#    ax.scatter(np.cos(l)*r*it, np.zeros(l.size)-it+1, np.sin(l)*r*it)

ax.plot((np.cos(l))*2*r, np.zeros(l.size)+r, np.sin(l)*2*r)
ax.plot((np.cos(l))*3*r, np.zeros(l.size), np.sin(l)*3*r)
ax.plot((np.cos(l))*2*r, np.zeros(l.size)-r, np.sin(l)*2*r)
ax.plot(np.zeros(l.size), np.cos(l)*r, np.sin(l)*r+2*r)

ax.set_xlabel(r'X')
ax.set_ylabel(r'Y')
ax.set_zlabel(r'Z')
#np.set_printoptions(precision=3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 0, 'Z')

# %%
import pandas as pd
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D

df1 = pd.DataFrame(data=np.zeros(l.shape)); df1.columns = ['X']
df1['Y'] = np.cos(l); df1['Z'] = np.sin(l)

df2 = pd.DataFrame(data=np.cos(l)); df2.columns = ['X']
df2['Y'] = np.sin(df1['Y']); df2['Z'] = df1['Z']

df1 = pd.concat([df1, df2])
df1 = df1.reset_index()

pd.options.display.float_format = '{:.4f}'.format
df1.tail()
# Out:
#     index       X       Y      Z
# 15      5 -0.7660 -0.6933 0.6428
# 16      6 -0.8660 -0.7618 0.5000
# 17      7 -0.9397 -0.8074 0.3420
# 18      8 -0.9848 -0.8332 0.1736
# 19      9 -1.0000 -0.8415 0.0000

# %%
sns.set(style = "darkgrid")
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')

x = df1['X']
y = df1['Y']
z = df1['Z']

ax.scatter(x, y, z)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
